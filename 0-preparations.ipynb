# %% [markdown]
# *The environment needs to have lxml and openssl. This can be installed via Anaconda Navigator*
#
# From Windows' Start menu, launch Anaconda Prompt (inside Anaconda).
# Run:
#
# ```
# $ conda install -c anaconda lxml
# $ conda install -c anaconda openssl
# ```

# %% [markdown]
# **Step 1. Set up emulab geni-lib package for CloudLab**

# %%
# !cd barnstorm-geni-lib-95b218670744 & python setup.py build
# Out:
# running build
# running build_py
# creating build
# creating build\lib
# creating build\lib\ccloud
# copying ccloud\endpoints.py -> build\lib\ccloud
# copying ccloud\__init__.py -> build\lib\ccloud
# creating build\lib\geni
# copying geni\constants.py -> build\lib\geni
# copying geni\exceptions.py -> build\lib\geni
# copying geni\namespaces.py -> build\lib\geni
# copying geni\portal.py -> build\lib\geni
# copying geni\tempfile.py -> build\lib\geni
# copying geni\types.py -> build\lib\geni
# copying geni\urn.py -> build\lib\geni
# copying geni\util.py -> build\lib\geni
# copying geni\warnings.py -> build\lib\geni
# copying geni\_coreutil.py -> build\lib\geni
# copying geni\__init__.py -> build\lib\geni
# creating build\lib\ccloud\api
# copying ccloud\api\g5k.py -> build\lib\ccloud\api
# copying ccloud\api\__init__.py -> build\lib\ccloud\api
# creating build\lib\geni\admin
# copying geni\admin\flowvisor.py -> build\lib\geni\admin
# copying geni\admin\foam.py -> build\lib\geni\admin
# copying geni\admin\germ.py -> build\lib\geni\admin
# copying geni\admin\oess.py -> build\lib\geni\admin
# copying geni\admin\vts.py -> build\lib\geni\admin
# copying geni\admin\__init__.py -> build\lib\geni\admin
# creating build\lib\geni\aggregate
# copying geni\aggregate\amtypes.py -> build\lib\geni\aggregate
# copying geni\aggregate\apis.py -> build\lib\geni\aggregate
# copying geni\aggregate\apt.py -> build\lib\geni\aggregate
# copying geni\aggregate\cloudlab.py -> build\lib\geni\aggregate
# copying geni\aggregate\context.py -> build\lib\geni\aggregate
# copying geni\aggregate\core.py -> build\lib\geni\aggregate
# copying geni\aggregate\core_openflow.py -> build\lib\geni\aggregate
# copying geni\aggregate\exceptions.py -> build\lib\geni\aggregate
# copying geni\aggregate\exogeni.py -> build\lib\geni\aggregate
# copying geni\aggregate\frameworks.py -> build\lib\geni\aggregate
# copying geni\aggregate\instageni.py -> build\lib\geni\aggregate
# copying geni\aggregate\instageni_openflow.py -> build\lib\geni\aggregate
# copying geni\aggregate\opengeni.py -> build\lib\geni\aggregate
# copying geni\aggregate\pgutil.py -> build\lib\geni\aggregate
# copying geni\aggregate\protogeni.py -> build\lib\geni\aggregate
# copying geni\aggregate\transit.py -> build\lib\geni\aggregate
# copying geni\aggregate\user.py -> build\lib\geni\aggregate
# copying geni\aggregate\vts.py -> build\lib\geni\aggregate
# copying geni\aggregate\__init__.py -> build\lib\geni\aggregate
# creating build\lib\geni\minigcf
# copying geni\minigcf\amapi2.py -> build\lib\geni\minigcf
# copying geni\minigcf\amapi3.py -> build\lib\geni\minigcf
# copying geni\minigcf\chapi2.py -> build\lib\geni\minigcf
# copying geni\minigcf\config.py -> build\lib\geni\minigcf
# copying geni\minigcf\util.py -> build\lib\geni\minigcf
# copying geni\minigcf\__init__.py -> build\lib\geni\minigcf
# creating build\lib\geni\model
# copying geni\model\base.py -> build\lib\geni\model
# copying geni\model\compute.py -> build\lib\geni\model
# copying geni\model\util.py -> build\lib\geni\model
# copying geni\model\__init__.py -> build\lib\geni\model
# creating build\lib\geni\rspec
# copying geni\rspec\base.py -> build\lib\geni\rspec
# copying geni\rspec\egext.py -> build\lib\geni\rspec
# copying geni\rspec\igext.py -> build\lib\geni\rspec
# copying geni\rspec\igutil.py -> build\lib\geni\rspec
# copying geni\rspec\oessad.py -> build\lib\geni\rspec
# copying geni\rspec\ofad.py -> build\lib\geni\rspec
# copying geni\rspec\ofrequest.py -> build\lib\geni\rspec
# copying geni\rspec\pg.py -> build\lib\geni\rspec
# copying geni\rspec\pgad.py -> build\lib\geni\rspec
# copying geni\rspec\pgmanifest.py -> build\lib\geni\rspec
# copying geni\rspec\stitching.py -> build\lib\geni\rspec
# copying geni\rspec\vts.py -> build\lib\geni\rspec
# copying geni\rspec\vtsad.py -> build\lib\geni\rspec
# copying geni\rspec\vtsmanifest.py -> build\lib\geni\rspec
# copying geni\rspec\__init__.py -> build\lib\geni\rspec
# creating build\lib\geni\support
# copying geni\support\ipython.py -> build\lib\geni\support
# copying geni\support\__init__.py -> build\lib\geni\support
# creating build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\emuext.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\enodeb.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\epcexc.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\epclan.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\epcnode.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\pndefs.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\pnext.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\rflink.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\ue.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\userdata.py -> build\lib\geni\rspec\emulab
# copying geni\rspec\emulab\__init__.py -> build\lib\geni\rspec\emulab
# running build_scripts
# creating build\scripts-2.7
# copying and adjusting tools\buildcontext\context-from-bundle -> build\scripts-2.7
# copying and adjusting tools\buildcontext\build-context -> build\scripts-2.7
# copying and adjusting tools\shell\genish -> build\scripts-2.7

# %%
# !cd barnstorm-geni-lib-95b218670744 & python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating geni_lib.egg-info
# writing requirements to geni_lib.egg-info\requires.txt
# writing geni_lib.egg-info\PKG-INFO
# writing top-level names to geni_lib.egg-info\top_level.txt
# writing dependency_links to geni_lib.egg-info\dependency_links.txt
# writing manifest file 'geni_lib.egg-info\SOURCES.txt'
# reading manifest file 'geni_lib.egg-info\SOURCES.txt'
# writing manifest file 'geni_lib.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build\bdist.win-amd64
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\ccloud
# creating build\bdist.win-amd64\egg\ccloud\api
# copying build\lib\ccloud\api\g5k.py -> build\bdist.win-amd64\egg\ccloud\api
# copying build\lib\ccloud\api\__init__.py -> build\bdist.win-amd64\egg\ccloud\api
# copying build\lib\ccloud\endpoints.py -> build\bdist.win-amd64\egg\ccloud
# copying build\lib\ccloud\__init__.py -> build\bdist.win-amd64\egg\ccloud
# creating build\bdist.win-amd64\egg\geni
# creating build\bdist.win-amd64\egg\geni\admin
# copying build\lib\geni\admin\flowvisor.py -> build\bdist.win-amd64\egg\geni\admin
# copying build\lib\geni\admin\foam.py -> build\bdist.win-amd64\egg\geni\admin
# copying build\lib\geni\admin\germ.py -> build\bdist.win-amd64\egg\geni\admin
# copying build\lib\geni\admin\oess.py -> build\bdist.win-amd64\egg\geni\admin
# copying build\lib\geni\admin\vts.py -> build\bdist.win-amd64\egg\geni\admin
# copying build\lib\geni\admin\__init__.py -> build\bdist.win-amd64\egg\geni\admin
# creating build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\amtypes.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\apis.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\apt.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\cloudlab.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\context.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\core.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\core_openflow.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\exceptions.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\exogeni.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\frameworks.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\instageni.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\instageni_openflow.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\opengeni.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\pgutil.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\protogeni.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\transit.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\user.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\vts.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\aggregate\__init__.py -> build\bdist.win-amd64\egg\geni\aggregate
# copying build\lib\geni\constants.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\exceptions.py -> build\bdist.win-amd64\egg\geni
# creating build\bdist.win-amd64\egg\geni\minigcf
# copying build\lib\geni\minigcf\amapi2.py -> build\bdist.win-amd64\egg\geni\minigcf
# copying build\lib\geni\minigcf\amapi3.py -> build\bdist.win-amd64\egg\geni\minigcf
# copying build\lib\geni\minigcf\chapi2.py -> build\bdist.win-amd64\egg\geni\minigcf
# copying build\lib\geni\minigcf\config.py -> build\bdist.win-amd64\egg\geni\minigcf
# copying build\lib\geni\minigcf\util.py -> build\bdist.win-amd64\egg\geni\minigcf
# copying build\lib\geni\minigcf\__init__.py -> build\bdist.win-amd64\egg\geni\minigcf
# creating build\bdist.win-amd64\egg\geni\model
# copying build\lib\geni\model\base.py -> build\bdist.win-amd64\egg\geni\model
# copying build\lib\geni\model\compute.py -> build\bdist.win-amd64\egg\geni\model
# copying build\lib\geni\model\util.py -> build\bdist.win-amd64\egg\geni\model
# copying build\lib\geni\model\__init__.py -> build\bdist.win-amd64\egg\geni\model
# copying build\lib\geni\namespaces.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\portal.py -> build\bdist.win-amd64\egg\geni
# creating build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\base.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\egext.py -> build\bdist.win-amd64\egg\geni\rspec
# creating build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\emuext.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\enodeb.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\epcexc.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\epclan.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\epcnode.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\pndefs.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\pnext.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\rflink.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\ue.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\userdata.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\emulab\__init__.py -> build\bdist.win-amd64\egg\geni\rspec\emulab
# copying build\lib\geni\rspec\igext.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\igutil.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\oessad.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\ofad.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\ofrequest.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\pg.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\pgad.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\pgmanifest.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\stitching.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\vts.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\vtsad.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\vtsmanifest.py -> build\bdist.win-amd64\egg\geni\rspec
# copying build\lib\geni\rspec\__init__.py -> build\bdist.win-amd64\egg\geni\rspec
# creating build\bdist.win-amd64\egg\geni\support
# copying build\lib\geni\support\ipython.py -> build\bdist.win-amd64\egg\geni\support
# copying build\lib\geni\support\__init__.py -> build\bdist.win-amd64\egg\geni\support
# copying build\lib\geni\tempfile.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\types.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\urn.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\util.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\warnings.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\_coreutil.py -> build\bdist.win-amd64\egg\geni
# copying build\lib\geni\__init__.py -> build\bdist.win-amd64\egg\geni
# byte-compiling build\bdist.win-amd64\egg\ccloud\api\g5k.py to g5k.pyc
# byte-compiling build\bdist.win-amd64\egg\ccloud\api\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\ccloud\endpoints.py to endpoints.pyc
# byte-compiling build\bdist.win-amd64\egg\ccloud\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\admin\flowvisor.py to flowvisor.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\admin\foam.py to foam.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\admin\germ.py to germ.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\admin\oess.py to oess.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\admin\vts.py to vts.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\admin\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\amtypes.py to amtypes.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\apis.py to apis.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\apt.py to apt.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\cloudlab.py to cloudlab.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\context.py to context.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\core.py to core.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\core_openflow.py to core_openflow.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\exceptions.py to exceptions.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\exogeni.py to exogeni.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\frameworks.py to frameworks.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\instageni.py to instageni.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\instageni_openflow.py to instageni_openflow.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\opengeni.py to opengeni.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\pgutil.py to pgutil.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\protogeni.py to protogeni.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\transit.py to transit.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\user.py to user.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\vts.py to vts.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\aggregate\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\constants.py to constants.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\exceptions.py to exceptions.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\minigcf\amapi2.py to amapi2.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\minigcf\amapi3.py to amapi3.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\minigcf\chapi2.py to chapi2.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\minigcf\config.py to config.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\minigcf\util.py to util.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\minigcf\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\model\base.py to base.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\model\compute.py to compute.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\model\util.py to util.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\model\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\namespaces.py to namespaces.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\portal.py to portal.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\base.py to base.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\egext.py to egext.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\emuext.py to emuext.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\enodeb.py to enodeb.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\epcexc.py to epcexc.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\epclan.py to epclan.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\epcnode.py to epcnode.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\pndefs.py to pndefs.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\pnext.py to pnext.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\rflink.py to rflink.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\ue.py to ue.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\userdata.py to userdata.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\emulab\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\igext.py to igext.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\igutil.py to igutil.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\oessad.py to oessad.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\ofad.py to ofad.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\ofrequest.py to ofrequest.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\pg.py to pg.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\pgad.py to pgad.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\pgmanifest.py to pgmanifest.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\stitching.py to stitching.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\vts.py to vts.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\vtsad.py to vtsad.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\vtsmanifest.py to vtsmanifest.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\rspec\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\support\ipython.py to ipython.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\support\__init__.py to __init__.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\tempfile.py to tempfile.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\types.py to types.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\urn.py to urn.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\util.py to util.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\warnings.py to warnings.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\_coreutil.py to _coreutil.pyc
# byte-compiling build\bdist.win-amd64\egg\geni\__init__.py to __init__.pyc
# creating build\bdist.win-amd64\egg\EGG-INFO
# installing scripts to build\bdist.win-amd64\egg\EGG-INFO\scripts
# running install_scripts
# running build_scripts
# creating build\bdist.win-amd64\egg\EGG-INFO\scripts
# copying build\scripts-2.7\build-context -> build\bdist.win-amd64\egg\EGG-INFO\scripts
# copying build\scripts-2.7\context-from-bundle -> build\bdist.win-amd64\egg\EGG-INFO\scripts
# copying build\scripts-2.7\genish -> build\bdist.win-amd64\egg\EGG-INFO\scripts
# copying geni_lib.egg-info\PKG-INFO -> build\bdist.win-amd64\egg\EGG-INFO
# copying geni_lib.egg-info\SOURCES.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying geni_lib.egg-info\dependency_links.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying geni_lib.egg-info\requires.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying geni_lib.egg-info\top_level.txt -> build\bdist.win-amd64\egg\EGG-INFO
# creating dist
# creating 'dist\geni_lib-0.9.4.7-py2.7.egg' and adding 'build\bdist.win-amd64\egg' to it
# removing 'build\bdist.win-amd64\egg' (and everything under it)
# Processing geni_lib-0.9.4.7-py2.7.egg
# Copying geni_lib-0.9.4.7-py2.7.egg to d:\anaconda3\envs\cloudlab\lib\site-packages
# Removing geni-lib 0.9.4.6 from easy-install.pth file
# Adding geni-lib 0.9.4.7 to easy-install.pth file
# Installing genish script to D:\Anaconda3\envs\CloudLab\Scripts
# Installing build-context script to D:\Anaconda3\envs\CloudLab\Scripts
# Installing context-from-bundle script to D:\Anaconda3\envs\CloudLab\Scripts
#
# Installed d:\anaconda3\envs\cloudlab\lib\site-packages\geni_lib-0.9.4.7-py2.7.egg
# Processing dependencies for geni-lib==0.9.4.7
# Searching for wrapt==1.11.1
# Best match: wrapt 1.11.1
# Processing wrapt-1.11.1-py2.7.egg
# wrapt 1.11.1 is already the active version in easy-install.pth
#
# Using d:\anaconda3\envs\cloudlab\lib\site-packages\wrapt-1.11.1-py2.7.egg
# Finished processing dependencies for geni-lib==0.9.4.7
# zip_safe flag not set; analyzing archive contents...

# %% [markdown]
# **Step 2: Reload geni-lib for the first time**
#
# On the top bar of this notebook, select `Kernel` and then `Restart`

# %% [markdown]
# **Step 3: Test emulab geni-lib installation**
#
# Executing this cell should produce an XML element with the following content:
#
# ```
# <rspec xmlns:client="http://www.protogeni.net/resources/rspec/ext/client/1" xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" xmlns:jacks="http://www.protogeni.net/resources/rspec/ext/jacks/1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.geni.net/resources/rspec/3" xsi:schemaLocation="http://www.geni.net/resources/rspec/3 http://www.geni.net/resources/rspec/3/request.xsd" type="request">
#   <rspec_tour xmlns="http://www.protogeni.net/resources/rspec/ext/apt-tour/1">
#     <description type="markdown">An example of constructing a profile with a single Xen VM.</description>
#     <instructions type="markdown">Wait for the profile instance to start, and then log in to the VM via the
# ssh port specified below.  (Note that in this case, you will need to access
# the VM through a high port on the physical host, since we have not requested
# a public IP address for the VM itself.)
# </instructions>
#   </rspec_tour>
#   <node client_id="node" exclusive="false">
#     <sliver_type name="emulab-xen"/>
#   </node>
# </rspec>
# ```

# %%
# %%writefile examples/test.py
"""An example of constructing a profile with a single Xen VM.

Instructions:
Wait for the profile instance to start, and then log in to the VM via the
ssh port specified below.  (Note that in this case, you will need to access
the VM through a high port on the physical host, since we have not requested
a public IP address for the VM itself.)
"""

import geni.portal as portal
import geni.rspec.pg as rspec

# Create a Request object to start building the RSpec.
request = portal.context.makeRequestRSpec()
 
# Create a XenVM
node = request.XenVM("node")

# Print the RSpec to the enclosing page.
portal.context.printRequestRSpec()
# Out:
# Overwriting examples/test.py

# %%
# !python examples/test.py
# Out:
# <rspec xmlns:client="http://www.protogeni.net/resources/rspec/ext/client/1" xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" xmlns:jacks="http://www.protogeni.net/resources/rspec/ext/jacks/1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.geni.net/resources/rspec/3" xsi:schemaLocation="http://www.geni.net/resources/rspec/3 http://www.geni.net/resources/rspec/3/request.xsd" type="request">
#   <rspec_tour xmlns="http://www.protogeni.net/resources/rspec/ext/apt-tour/1">
#     <description type="markdown">An example of constructing a profile with a single Xen VM.</description>
#     <instructions type="markdown">Wait for the profile instance to start, and then log in to the VM via the
# ssh port specified below.  (Note that in this case, you will need to access
# the VM through a high port on the physical host, since we have not requested
# a public IP address for the VM itself.)
# </instructions>
#   </rspec_tour>
#   <node client_id="node" exclusive="false">
#     <sliver_type name="emulab-xen"/>
#   </node>
# </rspec>

# %% [markdown]
# **Step 4: Make sure that you have a CloudLab-ready account:**
#
# See instructions at [the documentation](http://docs.cloudlab.us/users.html). This can be done either by
# - authorizing CloudLab to use you GENI account (go ahead and request to join the `PDC-edu-Lab` project), or
# - creating a new CloudLab account and request to join the `PDC-edu-Lab` project.

# %% [markdown]
# **Step 5: Generate SSH Keys for interaction with CloudLab instances **
#
# - On the terminal, generate a pair of public/private SSH keys with no password:
# ```
# > ssh-keygen -t rsa
# Generating public/private rsa key pair.
# Enter file in which to save the key (/home/lngo/.ssh/id_rsa):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /home/lngo/.ssh/id_rsa.
# Your public key has been saved in /home/lngo/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:l6oM32bbOKuzhksNak3FWSm7MojBerVuD4FI1j9RjUw lngo@localhost
# The key's randomart image is:
# +---[RSA 2048]----+
# |      oE+.       |
# |  .  .o=..       |
# |.o . .+o         |
# |+o .o.o    .     |
# |oo.o++ .S o      |
# |o o+++o  o       |
# | .o.=+. .        |
# | . .+=oo+o       |
# |   ..+B*=+.      |
# +----[SHA256]-----+
#
#  > more .ssh/id_rsa.pub
# ssh-rsa  LinhBNgo@surface4pro
# rsa
# ```
#
# - Login to `www.cloudlab.us`, select your username on the top right corner and select `Manage SSH Keys`.
#
# - Copy the content of the `id_rsa.pub` file into the `Key` box and click `Add Key`
